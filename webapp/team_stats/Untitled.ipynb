# %%
import matplotlib.pyplot as plt
import pandas as pd
 
from build_bar_plot_with_highlighted_two_teams import build_bar_plot_with_highlighted_two_teams, count_number_of_goals, build_bar_plot_two_teams, aggregate_current_dataframe, extract_plot_values 
from teams import TEAMS_INFO, TeamKeys

# %%
read_csv_17 = pd.read_csv('stats/17_18.csv')
read_csv_18 = pd.read_csv('stats/18_19.csv')
read_csv_19 = pd.read_csv('stats/19_20.csv')
read_csv_20 = pd.read_csv('stats/20_21.csv')
read_csv_21 = pd.read_csv('stats/21_22.csv')

csv_list = [read_csv_17, read_csv_18, read_csv_19, read_csv_20, read_csv_21]

data = aggregate_current_dataframe(read_csv_21) 
csv_list
# Out:
# [         data   time  matchday                home_team  \
#  0    11.08.17  19:45         1               Arsenal_FC
#  1    12.08.17  12:30         1               Watford_FC
#  2    12.08.17  15:00         1  West_Bromwich_Albion_FC
#  3    12.08.17  15:00         1               Chelsea_FC
#  4    12.08.17  15:00         1           Southampton_FC
#  ..        ...    ...       ...                      ...
#  375  13.05.18  15:00        38               Burnley_FC
#  376  13.05.18  15:00        38        Crystal_Palace_FC
#  377  13.05.18  15:00        38     Tottenham_Hotspur_FC
#  378  13.05.18  15:00        38    Huddersfield_Town_AFC
#  379  13.05.18  15:00        38           Southampton_FC
#
#                     away_team  goal_score_h_t  goal_score_a_t  at_1_half_h_t  \
#  0          Leicester_City_FC               4               3              2
#  1               Liverpool_FC               3               3              2
# ...

# %%
team1 = TeamKeys.MANCHESTER_UNITED
team2 = TeamKeys.EVERTON_FC


build_bar_plot_with_highlighted_two_teams(data, team1, team2, plot_name='Все голы', column='goal_score')

build_bar_plot_two_teams(csv_list, team1, team2, plot_name='Все по годам', column='goal_score')
# Out:
# C:\projects\dip\jupyter\build_bar_plot_with_highlighted_two_teams.py:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(labels, fontname='roboto', fontsize=12)
# findfont: Font family ['roboto'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['roboto'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Roboto'] not found. Falling back to DejaVu Sans.
# 4 0
# 2 1
# 1 1
# 3 3
# 1 1
# C:\projects\dip\jupyter\build_bar_plot_with_highlighted_two_teams.py:169: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(years_list, fontname='roboto', fontsize=12)
# C:\projects\dip\jupyter\build_bar_plot_with_highlighted_two_teams.py:172: UserWarning: FixedFormatter should only be used together with FixedLocator
# ...
